# %%
# %sql
use catalog dev;
use schema aryan;

# %%
# %sql
create table managers (id int, name string);

# %%
# %sql
describe table extended managers

# %%
# %sql
desc detail managers

# %%
# %sql
desc history managers

# %%
# %sql
insert into managers values (1, 'Aryan'), (2, 'Max')

# %%
# %sql
insert into dev.naval.emp values (5,'Aryan');

# %%
# %sql
select * from dev.aryan.managers version as of 1

# %%
# %sql
select * from dev.naval.emp timestamp as of '2026-04-08T04:33:26.000+00:00'

# %%
# %sql
create table dev.aryan.ice (id int, name string, age int) using iceberg

# %%
# %sql
describe extended dev.aryan.ice

# %%
# %sql
select * from dev.aryan.managers

# %%
# %sql
delete from dev.aryan.managers

# %%
# %sql
select * from dev.aryan.managers version as of 1

# %%
# %sql
select * from dev.aryan.managers

# %%
# %sql
restore table dev.aryan.managers version as of 1

# %%
# %sql
select * from dev.aryan.managers

# %%
# %sql
drop table managers

# %%
# %sql
undrop table dev.aryan.managers  -- undrop command default retention is 7 days or 168 hours

# %%
# %sql
