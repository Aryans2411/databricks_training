# %%
schema="Id integer, Name string, Gender string, Salary integer,Country string, Date string"

# %%
df=spark.readStream.schema(schema).csv("/Volumes/dev/naval/raw/stream/",header=True)

# %%
df.writeStream.option("checkpointLocation","/Volumes/dev/aryan/vol/checkpoint/").trigger(availableNow=True).toTable("dev.aryan.streaming")

# %%
# %sql
select * from dev.aryan.streaming

# %%
display(df)
