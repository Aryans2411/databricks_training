-- %%
%sql
create table dev.aryan.people(id int, name string, age int)

-- %%
%sql
desc extended dev.aryan.people

-- %%
describe detail dev.aryan.people

-- %%
desc detail dev.aryan.people

-- %%
insert into dev.aryan.people values(1, 'Aryan', 22);

-- %%
select * from dev.aryan.people

-- %%
insert into dev.aryan.people values(1,'Darshan', 22);
insert into dev.aryan.people values(1,'Harish', 22);
insert into dev.aryan.people values(1,'Vaibhav', 22);
insert into dev.aryan.people values(1,'Peyush', 22);
insert into dev.aryan.people values(1,'Divya', 22);
insert into dev.aryan.people values(1,'Ankan', 22);
insert into dev.aryan.people values(1,'Aryan', 22);

-- %%
optimize dev.aryan.people
zorder by id

-- %%
vacuum dev.aryan.people retain 0 hours

-- %%
create table dev.aryan.tpch_order as
select * from samples.tpch.orders

-- %%
select * from dev.aryan.tpch_order
