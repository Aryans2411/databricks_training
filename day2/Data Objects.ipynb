-- %%
create schema if not exists dev.aryan

-- %%
create table if not exists dev.aryan.products (
  id int,
  name string,
  price double,
  category string
)

-- %%
insert into dev.aryan.products
values (1, 'Product A', 10.0, 'Category X'), (2, 'Product B', 20.0, 'Category Y')

-- %%
select * from samples.nyctaxi.trips

-- %%
create table if not exists dev.aryan.houses as 
SELECT * FROM read_files('/Volumes/dev/naval/raw/housing.csv',format => 'csv')

-- %%
select location.longitude, sensor_data.body_temperature from read_files("/Volumes/dev/naval/raw/1.json")

-- %%
create table dev.aryan.transactions as 
select * from read_files("/Volumes/dev/naval/raw/part-00000-4ece8039-e05f-4114-8262-9d82c9ee1e62-c000.snappy.parquet")

-- %%
DROP TABLE dev.aryan.drivers
