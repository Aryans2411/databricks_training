# %%
# %sql
create or replace view dev.aryan_gold.top_customers as
select customer_id, sum(total_amount) as total from dev.aryan_silver.sales_cleaned group by customer_id order by total desc limit 3

# %%
# %sql
select * from dev.aryan_gold.top_customers
